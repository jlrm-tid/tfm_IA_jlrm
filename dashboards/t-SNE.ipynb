# %%
# Importar las bibliotecas necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# Cargar el dataset
# Asegúrate de reemplazar 'tu_dataset.csv' con la ruta a tu archivo
df = pd.read_csv('perfcounters_normal_running.csv')
df = df.drop(columns=[df.columns[0]])

# Estandarizar los datos
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# Aplicar t-SNE
tsne = TSNE(n_components=2, random_state=42)  # Cambia n_components a 3 si deseas una visualización 3D
tsne_results = tsne.fit_transform(scaled_data)

# Crear un DataFrame con los resultados de t-SNE
tsne_df = pd.DataFrame(data=tsne_results, columns=['Componente 1', 'Componente 2'])

# Visualizar los resultados
plt.figure(figsize=(8, 6))
plt.scatter(tsne_df['Componente 1'], tsne_df['Componente 2'], alpha=0.5)
plt.title('t-SNE - Componentes Principales')
plt.xlabel('Componente 1')
plt.ylabel('Componente 2')
plt.grid()
plt.show()

# %%
# Aplicar t-SNE
tsne = TSNE(n_components=3, random_state=42)  # Cambia n_components a 3 para visualización 3D
tsne_results = tsne.fit_transform(scaled_data)

# Crear un DataFrame con los resultados de t-SNE
tsne_df = pd.DataFrame(data=tsne_results, columns=['Componente 1', 'Componente 2', 'Componente 3'])

# Visualizar los resultados en 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(tsne_df['Componente 1'], tsne_df['Componente 2'], tsne_df['Componente 3'], alpha=0.5)

# Etiquetas y título
ax.set_title('t-SNE - Visualización 3D')
ax.set_xlabel('Componente 1')
ax.set_ylabel('Componente 2')
ax.set_zlabel('Componente 3')

plt.show()
